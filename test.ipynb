# %%
import bittensor as bt
archive = bt.subtensor('archive')
finney = bt.subtensor('finney')
# Out:
# 2024-07-13 02:46:26.621 |       INFO       | Connected to archive network and wss://archive.chain.opentensor.ai:443/.
# 2024-07-13 02:46:26.621 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-07-13 02:46:26.622 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-07-13 02:46:26.622 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# ...

# %%
old_coldkey': '5ES7RB2Qm45CwMNDZkTvfF2LxXPRtjzAdwHafrocftsTt1xy', 'new_coldkey': '5Gn9nv7Le5XYitfP86bdDuc92fUtcPGQtDM6vCcZur4fwUpy

# %%
old = '5ES7RB2Qm45CwMNDZkTvfF2LxXPRtjzAdwHafrocftsTt1xy'
new = '5Gn9nv7Le5XYitfP86bdDuc92fUtcPGQtDM6vCcZur4fwUpy'
print (finney.substrate.query("SubtensorModule", "StakingHotkeys", params=[ old]).value)
new_staking = finney.substrate.query("SubtensorModule", "StakingHotkeys", params=[ new]).value
print(new_staking )
print (finney.substrate.query("SubtensorModule", "Stake", params=[new_staking[0], old]).value)
print( finney.substrate.query("SubtensorModule", "Stake", params=[new_staking[0], new]).value)
# Out:
# []
# ['5Hddm3iBFD2GLT5ik7LZnT3XJUnRnN8PoeCFgGQgawUVKNm8']
# 0
# 41474319069584

# %%
finney.substrate.query("SubtensorModule", "Stake", params=["5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3", "5GjWE7iQjFfSVc4su4UcmuEzhfBE11CSDCnE9UrPmWxuxp8W"]).value
# Out:
# 0

# %%
finney.substrate.query("SubtensorModule", "Stake", params=["5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3", "5CUNWEwRBXJbGdDbGKm7cxjX3Jyk6QmREHa1QAgbNM3Fd3Hq"]).value
# Out:
# 17038004465325

# %%
import bittensor as bt
archive = bt.subtensor()
already_swapped = []
cur_block = archive.block
for val in archive.substrate.query_map('SubtensorModule', 'ColdkeyArbitrationBlock') :
    row = {'source': val[0].value, 'block': val[1].value }
    already_swapped.append( row)
# Out:
# 2024-07-13 02:46:33.081 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-07-13 02:46:33.082 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-07-13 02:46:33.082 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-07-13 02:46:34.087 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.

# %%
already_swapped.sort(key=lambda x: x['block'])

# %%
key_to_find = '5EAZ5d6Mi9KwngzSsDLTd9xGktn7s8hjLY1jXTK2XMBiB8VW'
index = next((i for i, item in enumerate(already_swapped) if item['source'] == key_to_find), None)
if index is not None:
    values_between = [item for item in already_swapped[index:] if item['block'] < cur_block]
    print(values_between)
else:
    print("Key not found")
# Out:
# [{'source': '5EAZ5d6Mi9KwngzSsDLTd9xGktn7s8hjLY1jXTK2XMBiB8VW', 'block': 3374929}, {'source': '5CRjyagZ6eSq4Ay4b8vTnwxgTpYvYeJTj2JCocw2DxGMop3F', 'block': 3374932}, {'source': '5Cz79nuJawMmzivHr3B2aNNhapFQSphSkdHqfFPPxSt5Lo8C', 'block': 3374942}, {'source': '5GnHjyrsGgiCuyjgmZoQtLsbJRxd67212jQZk9wtJER7oafE', 'block': 3374948}, {'source': '5Hh3yEmKKvWuFX2X7ja4No6GwAw976VzrjUwzktcg4xwEHXD', 'block': 3374951}, {'source': '5Dfnb8EF3xqQrwoh6NPXx3fhYLcEfzMv7GbTpSih9xt9bpUi', 'block': 3374952}, {'source': '5Gn4stHSF2Q9kDdaZrcJ559CBmEv2LJ3fFJavY4CoLq2mLSV', 'block': 3374966}, {'source': '5CD665wFh5s2kW4iDy8f71Gq4VXMWZvEQuLm7RJm3cHVWqAj', 'block': 3374982}, {'source': '5Hgky7XnBv2ghGMLtR13HKfZsH7E5gbXsTGs4karVF3iH6RL', 'block': 3375002}, {'source': '5F7go1TYhyK3RoKzrWtSWKr5EmUEyUDDfkMrmk4ta9HVtwvC', 'block': 3375013}, {'source': '5Ehf3YvfJgS1M8GFShQfMvJbs2Hg5wGLjMrR1uzHn6npoXRa', 'block': 3375016}, {'source': '5C8WZkZ3AKnewKoUtjS1xevLtG1JBun2QmEEwvvvSrBqsTcN', 'block': 3375027}, {'source': '5
# ...

# %%
len(values_between)
# Out:
# 32

# %%
import requests
import json
import re

pat = re.compile(r'class="break-words text-lg line-clamp-1">(5\w{47})')
pat_block = re.compile(r"(33\d{5})")
url = "https://keycheck.taostats.io/"
def get_destination_and_block(old_coldkey):
    url_ = url + old_coldkey
    response = requests.get(url_)
    response_text = response.text # html
    addy = pat.findall(response_text)[0]

    block = pat_block.findall(response_text)[0]
    return addy, block

for item in values_between:
    dets = get_destination_and_block(item['source'])
    item['dest'] = dets

values_between
# Out:
# [{'source': '5EAZ5d6Mi9KwngzSsDLTd9xGktn7s8hjLY1jXTK2XMBiB8VW',
#   'block': 3374929,
#   'dest': ('5G759yU31a9rLvSs9Z1nj2XnhGJ817E39QqRHk9UFffmBk2B', '3353329')},
#  {'source': '5CRjyagZ6eSq4Ay4b8vTnwxgTpYvYeJTj2JCocw2DxGMop3F',
#   'block': 3374932,
#   'dest': ('5FgyqjsViesRLb5VhBY24opN7qi5PM2TXu7JE8k6sWpCTDbf', '3353332')},
#  {'source': '5Cz79nuJawMmzivHr3B2aNNhapFQSphSkdHqfFPPxSt5Lo8C',
#   'block': 3374942,
#   'dest': ('5FufK7U1BnQaZYNyEm9JaFGfmxoixwKG1zwnCDFqCaUGjJEg', '3353342')},
#  {'source': '5GnHjyrsGgiCuyjgmZoQtLsbJRxd67212jQZk9wtJER7oafE',
#   'block': 3374948,
#   'dest': ('5CqSRaAMpQAQRps1ZqkgWwVJG8hTBVmv4mtuZwYT7SKga5jw', '3353348')},
#  {'source': '5Hh3yEmKKvWuFX2X7ja4No6GwAw976VzrjUwzktcg4xwEHXD',
#   'block': 3374951,
#   'dest': ('5GvL5MhdzmbseQBbWV72QtyJEmV9u6NsTzZtd1KhJ1ZynG8G', '3353351')},
#  {'source': '5Dfnb8EF3xqQrwoh6NPXx3fhYLcEfzMv7GbTpSih9xt9bpUi',
#   'block': 3374952,
#   'dest': ('5CPaYUUKYNKqCPHgNmAC9L3r1BiKZvnCzQmiVdgDA5xF9Ae8', '3353352')},
# ...

# %%
json_values = [{'source': item['source'], 'dest': item['dest'][0]} for item in values_between]
seen = set()
duplicates = set()
for item in json_values:
    if item['source'] in seen:
        duplicates.add(item['source'])
    else:
        seen.add(item['source'])
print(list(duplicates))
# Out:
# []

# %%
json_values = [{'source': item['source'], 'dest': item['dest'][0]} for item in values_between]
seen = set()
duplicates = set()
for item in json_values:
    if item['source'] in seen:
        duplicates.add(item['source'])
    else:
        seen.add(item['source'])
print(list(duplicates))
